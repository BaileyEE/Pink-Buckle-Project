# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#read in files and review
df_sires = pd.read_csv('PB_Sires_2021_Fees.csv')

df_sires.head(50)
# Out:
#                     Sire           Sires’ Sire                     Dam  \
# 0             AL CAPPONE        SHAWNE BUG LEO          TR DOUBLE CASH
# 1   AS GOOD AS NICK GETS           DR NICK BAR        MYSTICAL AVENGER
# 2    BHR FRENCHIES SOCKS        FRENCHMANS GUY         BHR MISSY SOCKS
# 3           BLAZIN HONOR       BLAZIN JETOLENA     VIKING VIXIONS LAST
# 4        BLAZIN JETOLENA     LENAS SUGAR DADDY       BLAZIN JENNIE JET
# 5       BULLSEYE BULLION         BULLY BULLION              TOP SHAWNE
# 6               CARRIZZO          DASH TA FAME             SOUTHASOFIA
# 7        CORONADO CARTEL         CORONA CARTEL          FIRST CAROLINA
# 8          DASHIN DYNAMO       FIRST DOWN DASH  RONAS COVER GIRL SI 94
# 9       DATS A FRENCHMAN        FRENCHMANS GUY       JUNOS DASHING CAT
# 10          DESIGNER RED      ON THE MONEY RED        PIN A ROSE ON ME
# 11           EPIC LEADER    CONFEDERATE LEADER        FIREWATER FIESTA
# 12        FEEL THE STING          DASH TA FAME         MP METER MY HAY
# 13      FIREWATER CANYON       FIRE WATER FLIT    MULBERRY CANYON MOON
# 14      FRECKLES TA FAME          DASH TA FAME     FRENCHMANS FRECKLES
# 15         FURYOFTHEWIND         CORONA CARTEL          DASHING PHOEBE
# 16     HP DASH TA FIESTA          DASH TA FAME        FIREWATER FIESTA
# 17  IMA SPECIAL KINDAGUY        FRENCHMANS GUY               MELT AWAY
# 18      IMA TALENTED GUY        FRENCHMANS GUY      TALENTS DARK ANGEL
# 19             IRISH PAY  PADDYS IRISH WHISKEY           RAISE THE PAY
# 20          JESSES TOPAZ         MR JESS PERRY            PADDYS TOPAZ
# 21            JL SIROCCO          DASH TA FAME                  SOLARA
# 22    JOHNNY REB JACKSON    CONFEDERATE LEADER        CAUSE FOR A KISS
# 23            KVN CORONA         CORONA CARTEL  EXECUTIVE LOOKS SI 113
# 24    LUCKY WONDER HORSE       FIRST DOWN DASH        ROSAS CANTINA CC
# 25          MOSCATO FAME          DASH TA FAME    MULBERRY CANYON MOON
# 26         MP HOT HAYDAY  PC FRENCHMANS HAYDAY           MP NELLE WOOD
# 27    MR SASSY FRENCHMAN        FRENCHMANS GUY            JESS SASS ME
# 28          MS TRUCOSEIX             TRES SEIS    DONTBLINKORULEMISSME
# 29     NO PRESSURE ON ME          LEO NICK BAR    SX FRENCHMANS VANILA
# 30      ONE FAMOUS EAGLE         MR JESS PERRY         ONE FAMOUS LADY
# 31      PC REDWOOD MANNY             SUN FROST           MANDRIFT MARI
# 32     PCR PINK CADILLAC          DASH TA FAME        MY FAVORITE LANE
# 33          PRIME TALENT         CORONA CARTEL        OH HOW YOU SHINE
# 34  PYC PAINT YOUR WAGON         CORONA CARTEL          DASHIN FOLLIES
# 35                ROARRR             TRES SEIS          DASH TA VANILA
# 36        SHAWNE BUG LEO            SHAWNE BUG          COUNTESS EDITH
# 37       SLICK BY DESIGN          DESIGNER RED          DREAMS OF BLUE
# 38        SLYE BY DESIGN       SLICK BY DESIGN     KELLIES CHICK SI 98
# 39     STREAKIN BOON DOX     A STREAK OF FLING            PC JOESY DOX
# 40      THE GOODBYE LANE        LANES LEINSTER           SWIFT GOODBYE
# 41    THIS GUYZ A KEEPER        FRENCHMANS GUY  CLASSIC KEEPSAKE SI 98
# 42           TRAFFIC GUY        FRENCHMANS GUY         EVENING TRAFFIC
# 43             TRES SEIS               SIXARUN       OUR THIRD DELIGHT
# 44       WINNERS VERSION          HOLLAND EASE     THE JUBILEE DIAMOND
# 45     A GUY WITH PROOF         FRENCHMANS GUY          AMERICAN PROOF
# 46        COWBOYS CARTEL         CORONA CARTEL           DASHING FOLLY
# 47           JUST WINNIN       Winners Version       TR DASHING BADGER
# 48    SHEIK JEAN FLY HTT        VICTORY FLY VM             TINY MARTHA
# 49   SW THE GAME CHANGER   High Rate of Return                  Ailena
#
#                 Dam Sire     Color             Fee  Unnamed: 6  Unnamed: 7
# 0      TEXAS HIGH DASHER    Sorrel            1750         NaN         NaN
# 1   STAUNCH AVENGER (TB)    Sorrel            3000         NaN         NaN
# 2              CAN HE GO    Sorrel            4500         NaN         NaN
# 3            POWER TRAIN    Sorrel            1500         NaN         NaN
# 4           JET OF HONOR    Sorrel            5000         NaN         NaN
# 5             SHAWNE BUG    Sorrel            2000         NaN         NaN
# 6          SAIL ON BUNNY    Sorrel            2500         NaN         NaN
# 7          MR JESS PERRY     Brown            3000         NaN         NaN
# 8             RONAS RYON  Chestnut            1750         NaN         NaN
# 9          JUNO DAT CASH  Chestnut            3000         NaN         NaN
# 10          MR JET MAGIC    Sorrel            5000         NaN         NaN
# 11       FIRE WATER FLIT      Gray            4500         NaN         NaN
# 12  PC FRENCHMANS HAYDAY  Chestnut            3000         NaN         NaN
# 13     MARTHAS SIX MOONS      Gray            2500         NaN         NaN
# 14        FRENCHMANS GUY    Sorrel            3500         NaN         NaN
# 15         DASH FOR CASH       Bay            4000         NaN         NaN
# 16       FIRE WATER FLIT    Sorrel            1500         NaN         NaN
# 17        SPECIAL LEADER  Palomino            2000         NaN         NaN
# 18        FLAMING TALENT  Buckskin            1700         NaN         NaN
# 19         PREFERRED PAY       Bay            2000         NaN         NaN
# 20  PADDYS IRISH WHISKEY  Buckskin            2000         NaN         NaN
# 21         BAND OF AZURE    Sorrel            3500         NaN         NaN
# 22       CAUSE ITS MONEY     Black            1500         NaN         NaN
# 23      EXECUTIVE MENACE      Gray            5000         NaN         NaN
# 24         CORONA CARTEL  Buckskin            3000         NaN         NaN
# 25     MARTHAS SIX MOONS  Chestnut            1750         NaN         NaN
# 26          LONE DRIFTER  Palomino            1000         NaN         NaN
# 27         MR JESS PERRY  Palomino            3000         NaN         NaN
# 28                VOLCOM      Gray            1500         NaN         NaN
# 29        FRENCHMANS GUY    Sorrel            2000         NaN         NaN
# 30        CHICKS BEDUINO    Sorrel  PRIVATE TREATY         NaN         NaN
# 31           MANDRIFT 78  Buckskin            1500         NaN         NaN
# 32        LANES LEINSTER    Sorrel            2000         NaN         NaN
# 33      COUP DE KAS (TB)       Bay            2000         NaN         NaN
# 34      STRAWFLY SPECIAL     Brown            6000         NaN         NaN
# 35          DASH TA FAME       Bay            2500         NaN         NaN
# 36    COUNT GIACOMO (TB)    Sorrel            4000         NaN         NaN
# 37       DREAM ON DANCER     Black            3000         NaN         NaN
# 38              DARKELLY     Black            1000         NaN         NaN
# 39         BOON DOX JOHN  Bay Roan            2500         NaN         NaN
# 40          DASH TA FAME     Brown            6500         NaN         NaN
# 41         DASH FOR CASH  Palomino            2000         NaN         NaN
# 42     DASH THRU TRAFFIC  Buckskin            2500         NaN         NaN
# 43     REB'S POLICY (TB)     Brown            9800         NaN         NaN
# 44        RUNAWAY WINNER     Brown            2500         NaN         NaN
# 45           EXTRA PROOF  Chestnut            2500         NaN         NaN
# 46       FIRST DOWN DASH    Sorrel            1750         NaN         NaN
# 47        MR ILLUMINATOR     BLACK            2000         NaN         NaN
# 48     MARTHAS SIX MOONS       Bay            2000         NaN         NaN
# 49           Dash McCall  Palomino            1500         NaN         NaN

# %%
sire_fees=df_sires.iloc[:,[0,5]] #drop columns with information that are not to be used in our anaylisis

#Convert the objects to string

sire_fees.astype(str)
fees=sire_fees['Fee'].value_counts()
sire_fees=sire_fees.drop([30])
sire_fees=sire_fees['Fee'].astype(int)

# %%
# Calculate some basic statistics of the Stud Fees
print("The Average Stud fee is $",sire_fees.mean())
print("The most common Stud fee is $",sire_fees.mode())
# Out:
# The Average Stud fee is $ 2846.938775510204
# The most common Stud fee is $ 0    2000
# dtype: int64

# %%
#Create Plot of Stud Fees
fees.plot(kind="bar", color="C6")
plt.title(" 2021 Pink Buckle Stud Fees ")
plt.ylabel('No. of Stallions')
plt.xlabel("Stud fee ($USD)")
# Out:
# Text(0.5, 0, 'Stud fee ($USD)')

# %% [markdown]
# # Pink Buckle Barrel Racing - Stallion Analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#read in results files
pbf_18 = pd.read_csv('./CSV_Analysis/2018_Futurity')
pbf_19 = pd.read_csv('./CSV_Analysis/2019_Futurity')
pbf_20 = pd.read_csv('./CSV_Analysis/2020_Futurity')

# %%
'''Payouts are based on Divisions which are a set time period off the fastest time.  This is called a D.  
We will assign a D to each horse per run for each year.  Later this will be helpful to see if any particular sire's offspring
are more likely to be in any particular division, we will also allocate the first 20 horses in both Ds as money winners per the curtent payout format'''

def AssignDs(df, colstring1, new_col_name):
    '''
    assign D's based on division split, and give the first 20 horses in each D the status of "Money Winner"
    Input: df = Dataframe, 
    colstring1 = String - the time column on the data frame to be placing D's in.
    new_col_name = String - the column name the Ds will be placed in
    output: adds column placeing horse in 1D or 2D
    '''
    D_split = 0.75 # D second split for the PB futurity and Derby
    
    df[new_col_name]= np.where(df[colstring1] > (df[colstring1].min()+D_split), 2, 1)
    
    place_col_name = colstring1 +' Place' #create a value to pull the money winners by placing
    df['Money_Winner'] = np.where(df[place_col_name]<= 20, 1,0) #calls out money winners in 1D
    df.sort_values(colstring1, inplace = True) #sort so we can call the 2D $ winner index  
    two_d = df[df[new_col_name] > 1].index[0] #get the next 20 places, 
    df.iloc[two_d:(two_d+19),df.columns.get_loc('Money_Winner')] = 1 #assign 1 for money winner
    return df

# %%
# Denote which horses won money and which D (industry slang for division) they placed in
pbf_18 = AssignDs(pbf_18, '1st Go', '1stGoD')
pbf_19 = AssignDs(pbf_19, '1st Go', '1stGoD')
pbf_20 = AssignDs(pbf_20, '1st Go', '1stGoD')
pbf_18 = AssignDs(pbf_18, '2nd Go', '2ndGoD')
pbf_19 = AssignDs(pbf_19, '2nd Go', '2ndGoD')
pbf_20 = AssignDs(pbf_20, '2nd Go', '2ndGoD')

# %%
#Concatenate all 3 years results into one dataframe
pbf = pd.concat([pbf_18, pbf_19,pbf_20]).drop(columns = ['Unnamed: 0','#'])
pbf['Sire'] = pbf['Sire'].str.upper() # move all words to upper case to join with 2021 stud fee info from Qstallions.com

display(pbf.head())
display(pbf.columns)
# Out:
#     1st Go Place                 Horse     Age     Color       Sex  \
# 59          63.0  Tee It Up In My Sox   2014.0  Chestnut      Mare
# 3            4.0    Jets Heart N Soul   2014.0  Chestnut   Gelding
# 5            6.0     High Cotton Lane   2014.0  Chestnut  Stallion
# 12          13.0     Smooth Movin Guy   2014.0  Buckskin   Gelding
# 0            1.0       French Goodbye   2014.0  Palomino   Gelding
#
#                    Sire                   Dam            Dam's Sire  \
# 59  BHR FRENCHIES SOCKS  BA Tee It Up Ta Fame   Tee It Up In My Sox
# 3       BLAZIN JETOLENA   Mistys Dash of Fame          Dash Ta Fame
# 5      THE GOODBYE LANE  HMB Soon Tobe Famous          Dash Ta Fame
# 12         A SMOOTH GUY  Full A Irish Whiskey  Paddys Irish Whiskey
# 0      THE GOODBYE LANE        Two Fools Gold        Frenchmans Guy
#
#                 Rider  1st Go  2nd Go Place  2nd Go  1stGoD  Money_Winner  \
# 59       Lacey Harmon  22.229           1.0  16.779       2             1
# 3   Jolene Montgomery  16.988           2.0  16.818       1             1
# 5         Paige Jones  17.021           3.0  16.829       1             1
# 12     Dustin Angelle  17.305           4.0  16.838       1             1
# 0        Vauna Walker  16.567           5.0  16.936       1             1
#
#     2ndGoD
# 59       1
# 3        1
# 5        1
# 12       1
# 0        1
# Index(['1st Go Place', 'Horse', 'Age', 'Color', 'Sex', 'Sire', 'Dam',
#        'Dam's Sire', 'Rider', '1st Go', '2nd Go Place', '2nd Go', '1stGoD',
#        'Money_Winner', '2ndGoD'],
#       dtype='object')

# %%
df = pbf.pivot_table(
    index = ['Sire','Horse'],
    values = ['1st Go','2nd Go','1st Go Place', '2nd Go Place','1stGoD','2ndGoD','Money_Winner'] 
)


df['1D Horse']=(df[df == 1].sum(axis = 1)) #assigns a value of 1 for each run a horse had <.75 seconds off the fastest time in their year


'''Tipped barrels were considered no time at this event and assigned a time of 999.00 for the round. 
Including this in the average will unfairly weight the times in favor of those whose offspring did not tip a barrel.
This should not fault the horse as it could easily be rider error.  Being the results have no way of indicating a horse did not make a run 
and took a no time or if they tipped all 3 barrels, no times were not included in the average. 
    '''
    
df['Tipped'] = (df[df == 999.000].sum(axis = 1))

df.replace(to_replace = {'Tipped': {999.0 : 1, 1998.0 : 2}}, inplace = True)
totals = df.groupby(['Sire']).sum() # calculate sum of statistics for sires
oneDcount = df.groupby(['Sire'])
siredata = df.groupby(['Sire']).mean()
siredata['total_offspring'] = df.groupby(['Sire']).size() 
#remove 999.00 to become nan so they aren't included in the average time
(df.replace(to_replace =  {999.0 :np.nan}, inplace = True)) 
df = df.dropna(subset=['1st Go', '2nd Go']) #remove any horse that had no time for both go's  The horse may not have competed at all. 
df['Average'] = df['1st Go']+df['2nd Go']
display(df)

siredata.head(30)
# Out:
# <ipython-input-53-8fdd2f320a1c>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Average'] = df['1st Go']+df['2nd Go']
#                                        1st Go  1st Go Place  1stGoD  2nd Go  \
# Sire            Horse
# A SMOOTH GUY    A Smart Guy            17.446          30.0     1.0  17.495
#                 A Smooth Flit          18.495         126.0     2.0  23.143
#                 A Smooth Hula Queen    18.566         116.0     2.0  18.501
#                 A Smooth Movin Lucy    18.132          97.0     2.0  18.258
#                 A Smooth Twister       18.215          50.0     2.0  18.147
# ...                                       ...           ...     ...     ...
# TRES SEIS       Tres N Firewater       18.186         104.0     2.0  17.956
#                 Tufferenell            22.381         160.0     2.0  22.147
#                 TwoBigFourMyBritches   17.520          33.0     1.0  17.393
# WINNERS VERSION Lil Famous Winner      18.238         111.0     2.0  18.302
#                 The Right Version      17.102           3.0     1.0  17.511
#
#                                        2nd Go Place  2ndGoD  Money_Winner  \
# Sire            Horse
# A SMOOTH GUY    A Smart Guy                    25.0     1.0             0
#                 A Smooth Flit                 168.0     2.0             1
#                 A Smooth Hula Queen           111.0     2.0             0
#                 A Smooth Movin Lucy           114.0     2.0             0
#                 A Smooth Twister               48.0     2.0             0
# ...                                             ...     ...           ...
# TRES SEIS       Tres N Firewater               87.0     2.0             0
#                 Tufferenell                   151.0     2.0             0
#                 TwoBigFourMyBritches           17.0     1.0             1
# WINNERS VERSION Lil Famous Winner             116.0     2.0             0
#                 The Right Version              27.0     1.0             0
#
#                                        1D Horse  Tipped  Average
# Sire            Horse
# A SMOOTH GUY    A Smart Guy                 2.0     0.0   34.941
#                 A Smooth Flit               1.0     0.0   41.638
#                 A Smooth Hula Queen         0.0     0.0   37.067
#                 A Smooth Movin Lucy         0.0     0.0   36.390
#                 A Smooth Twister            0.0     0.0   36.362
# ...                                         ...     ...      ...
# TRES SEIS       Tres N Firewater            0.0     0.0   36.142
#                 Tufferenell                 0.0     0.0   44.528
#                 TwoBigFourMyBritches        3.0     0.0   34.913
# WINNERS VERSION Lil Famous Winner           0.0     0.0   36.540
#                 The Right Version           2.0     0.0   34.613
#
# [394 rows x 10 columns]
#                           1st Go  1st Go Place    1stGoD      2nd Go  \
# Sire
# A SMOOTH GUY           49.500969     88.312500  1.750000   49.672063
# AS GOOD AS NICK GETS  999.000000    195.000000  2.000000  999.000000
# BHR FRENCHIES SOCKS    59.897833     85.000000  1.770833   59.707125
# BLAZIN JETOLENA        94.023333     75.564103  1.615385  120.180564
# BORN TA BE FAMOUS      20.370545    101.272727  1.818182  108.629636
# CARRIZZO              510.804500    169.500000  2.000000  513.825500
# CONFEDERATE LEADER     17.914000     73.000000  2.000000   18.286000
# CORONA CARTEL          17.963000     77.000000  2.000000   17.655000
# DASH TA FAME          508.300500     51.500000  2.000000   17.652500
# DASHIN DYNAMO          18.779000     88.833333  1.833333   17.960500
# DASHING GUY            18.579000    115.500000  2.000000   18.676500
# DATS A FRENCHMAN      671.942333    114.666667  2.000000  671.853667
# EDDIE STINSON         124.638000     72.459459  1.675676   72.341054
# FIREWATER CANYON      169.877154    121.923077  1.846154   94.003385
# FRENCHMANS GUY         22.390000     66.000000  2.000000   17.153000
# FURYOFTHEWIND          19.453308     98.153846  1.692308   95.775308
# GUYS EYE PAINT         17.875000     75.000000  2.000000   18.038000
# IRISH PAY              19.812000     85.615385  1.923077   19.486077
# JESSES TOPAZ           23.882000    183.000000  2.000000   18.639000
# JL SIROCCO             17.800500     64.000000  1.500000   18.376000
# LEAD THE FIELD         17.988000     82.000000  2.000000   18.476000
# MP JET TO THE SUN      18.335667     95.000000  1.833333   18.292167
# NO PRESSURE ON ME      17.972500     78.500000  1.500000   18.346333
# ONE FAMOUS EAGLE       21.426667    131.333333  2.000000  345.415333
# PC REDWOOD MANNY      118.582300    119.900000  2.000000   19.269800
# PG DRY FIRE            18.267200     91.800000  1.800000   19.489200
# PRIME TALENT          263.188500     89.750000  1.875000  263.646625
# PYC PAINT YOUR WAGON   20.876571     94.142857  2.000000   19.105000
# SHAWNE BUG LEO         18.909957     74.956522  1.695652   61.752348
# SLICK BY DESIGN        60.234901     86.577465  1.704225   60.077056
#
#                       2nd Go Place    2ndGoD  Money_Winner  1D Horse  \
# Sire
# A SMOOTH GUY             91.781250  1.812500      0.156250  0.593750
# AS GOOD AS NICK GETS    194.000000  2.000000      0.000000  0.000000
# BHR FRENCHIES SOCKS      78.916667  1.645833      0.250000  0.833333
# BLAZIN JETOLENA          90.564103  1.743590      0.256410  0.923077
# BORN TA BE FAMOUS        92.000000  1.909091      0.090909  0.363636
# CARRIZZO                177.500000  2.000000      0.500000  0.500000
# CONFEDERATE LEADER      101.000000  2.000000      0.000000  0.000000
# CORONA CARTEL            49.000000  1.000000      0.000000  1.000000
# DASH TA FAME             36.500000  1.500000      0.500000  1.000000
# DASHIN DYNAMO            74.333333  1.833333      0.000000  0.333333
# DASHING GUY             127.500000  2.000000      0.000000  0.000000
# DATS A FRENCHMAN        102.666667  1.666667      0.000000  0.333333
# EDDIE STINSON            75.189189  1.567568      0.243243  1.027027
# FIREWATER CANYON         96.461538  1.923077      0.000000  0.230769
# FRENCHMANS GUY           13.000000  1.000000      1.000000  2.000000
# FURYOFTHEWIND            97.153846  1.615385      0.461538  1.153846
# GUYS EYE PAINT           94.000000  2.000000      0.000000  0.000000
# IRISH PAY                86.846154  1.846154      0.307692  0.538462
# JESSES TOPAZ            132.000000  2.000000      0.000000  0.000000
# JL SIROCCO               89.500000  1.500000      0.000000  1.000000
# LEAD THE FIELD          110.000000  2.000000      0.000000  0.000000
# MP JET TO THE SUN        84.833333  1.833333      0.166667  0.500000
# NO PRESSURE ON ME        77.500000  1.666667      0.000000  0.833333
# ONE FAMOUS EAGLE        124.000000  2.000000      0.333333  0.333333
# PC REDWOOD MANNY        100.400000  2.000000      0.200000  0.200000
# PG DRY FIRE             113.800000  2.000000      0.200000  0.400000
# PRIME TALENT             91.625000  1.625000      0.250000  0.750000
# PYC PAINT YOUR WAGON     59.000000  1.571429      0.428571  0.857143
# SHAWNE BUG LEO           81.130435  1.739130      0.347826  0.913043
# SLICK BY DESIGN          74.915493  1.591549      0.323944  1.042254
#
#                         Tipped  total_offspring
# Sire
# A SMOOTH GUY          0.062500               32
# AS GOOD AS NICK GETS  2.000000                1
# BHR FRENCHIES SOCKS   0.083333               24
# BLAZIN JETOLENA       0.179487               39
# BORN TA BE FAMOUS     0.090909               11
# CARRIZZO              1.000000                2
# CONFEDERATE LEADER    0.000000                1
# CORONA CARTEL         0.000000                1
# DASH TA FAME          0.500000                2
# DASHIN DYNAMO         0.000000                6
# DASHING GUY           0.000000                2
# DATS A FRENCHMAN      1.333333                3
# EDDIE STINSON         0.162162               37
# FIREWATER CANYON      0.230769               13
# FRENCHMANS GUY        0.000000                1
# FURYOFTHEWIND         0.076923               13
# GUYS EYE PAINT        0.000000                1
# IRISH PAY             0.000000               13
# JESSES TOPAZ          0.000000                1
# JL SIROCCO            0.000000                2
# LEAD THE FIELD        0.000000                1
# MP JET TO THE SUN     0.000000                6
# NO PRESSURE ON ME     0.000000                6
# ONE FAMOUS EAGLE      0.333333                3
# PC REDWOOD MANNY      0.100000               10
# PG DRY FIRE           0.000000                5
# PRIME TALENT          0.500000                8
# PYC PAINT YOUR WAGON  0.000000                7
# SHAWNE BUG LEO        0.043478               23
# SLICK BY DESIGN       0.084507               71

# %%
#move totals to the dataframe of average times
siredata['Total_no-times'] = totals['Tipped']
siredata['1D Horse'] = totals['1D Horse']
siredata['Money_Winner'] = totals['Money_Winner']

#caluclates the sum of the (average 1st Go and 2nd Go for all offspring removing for 999.00
siredata['Adj Average_Time'] = ((df.groupby(['Sire']).mean()).loc[:,['1st Go','2nd Go']]).sum(axis = 1) 
#average placing is considered the total of the first and second go.  I chose to add the average of the first go, and second go for each sire to get this number.
siredata['Adj Average_placing'] = ((df.groupby(['Sire']).mean()).loc[:,['1st Go Place','2nd Go Place']]).mean(axis = 1)

# 1st Go, 2nd Go and average with all 999.00 included

siredata['Average_Time'] = (siredata.loc[:,['1st Go','2nd Go']]).sum(axis = 1) 
siredata['Average_placing'] = (siredata.loc[:,['1st Go Place','2nd Go Place']]).mean(axis = 1)

siredata.rename(columns = {'Tipped':'Normalized_penalties'}, inplace = True)
siredata.sort_values(by = ['Adj Average_Time', 'Total_no-times'] ,ascending=True, inplace=True)


siredata['pct1D']= 100*(siredata['1D Horse']/siredata['total_offspring']) # calculate percentage of offspring in the 1D
siredata['pctMoneyWinners'] = 100*(siredata['Money_Winner']/siredata['total_offspring']) # calculate percentage of offspring that earned money
siredata.head()
# Out:
#                       1st Go  1st Go Place  1stGoD      2nd Go  2nd Go Place  \
# Sire
# DATS A FRENCHMAN  671.942333    114.666667    2.00  671.853667    102.666667
# DASH TA FAME      508.300500     51.500000    2.00   17.652500     36.500000
# WINNERS VERSION   508.335000    127.500000    1.75  508.453250    134.000000
# CORONA CARTEL      17.963000     77.000000    2.00   17.655000     49.000000
# GUYS EYE PAINT     17.875000     75.000000    2.00   18.038000     94.000000
#
#                     2ndGoD  Money_Winner  1D Horse  Normalized_penalties  \
# Sire
# DATS A FRENCHMAN  1.666667             0       1.0              1.333333
# DASH TA FAME      1.500000             1       2.0              0.500000
# WINNERS VERSION   1.750000             0       2.0              1.000000
# CORONA CARTEL     1.000000             0       1.0              0.000000
# GUYS EYE PAINT    2.000000             0       0.0              0.000000
#
#                   total_offspring  Total_no-times  Adj Average_Time  \
# Sire
# DATS A FRENCHMAN                3             4.0           35.3880
# DASH TA FAME                    2             1.0           35.4470
# WINNERS VERSION                 4             4.0           35.5765
# CORONA CARTEL                   1             0.0           35.6180
# GUYS EYE PAINT                  1             0.0           35.9130
#
#                   Adj Average_placing  Average_Time  Average_placing  \
# Sire
# DATS A FRENCHMAN                50.00    1343.79600       108.666667
# DASH TA FAME                    34.00     525.95300        44.000000
# WINNERS VERSION                 64.25    1016.78825       130.750000
# CORONA CARTEL                   63.00      35.61800        63.000000
# GUYS EYE PAINT                  84.50      35.91300        84.500000
#
#                        pct1D  pctMoneyWinners
# Sire
# DATS A FRENCHMAN   33.333333              0.0
# DASH TA FAME      100.000000             50.0
# WINNERS VERSION    50.000000              0.0
# CORONA CARTEL     100.000000              0.0
# GUYS EYE PAINT      0.000000              0.0

# %% [markdown]
# <p> Now lets read in the stud fees,  and see if there is any correlation to the placings.  We will also eliminate any sires whose offspring from the 2021 breeding season are no longer eligible for the competition. </p>

# %%
df_sires = pd.read_csv('PB_Sires_2021_Fees.csv')
sire_fees=df_sires.iloc[:,[0,5]] #drop columns with information that are not to be used in our anaylisis
df2 = pd.merge(siredata, sire_fees, on = 'Sire', how = 'outer')
df2.columns
# Out:
# Index(['Sire', '1st Go', '1st Go Place', '1stGoD', '2nd Go', '2nd Go Place',
#        '2ndGoD', 'Money_Winner', '1D Horse', 'Normalized_penalties',
#        'total_offspring', 'Total_no-times', 'Adj Average_Time',
#        'Adj Average_placing', 'Average_Time', 'Average_placing', 'pct1D',
#        'pctMoneyWinners', 'Fee'],
#       dtype='object')

# %%
df2 = df2.drop(columns = (['1st Go', '1st Go Place', '1stGoD', '2nd Go', '2nd Go Place',
       '2ndGoD']))

# %%
display(df2)
no_entries = (df2['1D Horse'].isna()).sum() # count the number of 2021 sires who have had not had offspring compete
no_entries
ineligible = (df2['Fee'].isna()).sum()
print('{} Sires have not had any offspring run in the Futurity, {} sires are no longer eligible as of the 2021 breeding season'.format(no_entries, ineligible))
# Out:
#                    Sire  Money_Winner  1D Horse  Normalized_penalties  \
# 0      DATS A FRENCHMAN           0.0       1.0              1.333333
# 1          DASH TA FAME           1.0       2.0              0.500000
# 2       WINNERS VERSION           0.0       2.0              1.000000
# 3         CORONA CARTEL           0.0       1.0              0.000000
# 4        GUYS EYE PAINT           0.0       0.0              0.000000
# ..                  ...           ...       ...                   ...
# 57    A GUY WITH PROOF            NaN       NaN                   NaN
# 58       COWBOYS CARTEL           NaN       NaN                   NaN
# 59          JUST WINNIN           NaN       NaN                   NaN
# 60   SHEIK JEAN FLY HTT           NaN       NaN                   NaN
# 61  SW THE GAME CHANGER           NaN       NaN                   NaN
#
#     total_offspring  Total_no-times  Adj Average_Time  Adj Average_placing  \
# 0               3.0             4.0           35.3880                50.00
# 1               2.0             1.0           35.4470                34.00
# 2               4.0             4.0           35.5765                64.25
# 3               1.0             0.0           35.6180                63.00
# 4               1.0             0.0           35.9130                84.50
# ..              ...             ...               ...                  ...
# 57              NaN             NaN               NaN                  NaN
# 58              NaN             NaN               NaN                  NaN
# 59              NaN             NaN               NaN                  NaN
# 60              NaN             NaN               NaN                  NaN
# 61              NaN             NaN               NaN                  NaN
#
#     Average_Time  Average_placing       pct1D  pctMoneyWinners   Fee
# 0     1343.79600       108.666667   33.333333              0.0  3000
# 1      525.95300        44.000000  100.000000             50.0   NaN
# 2     1016.78825       130.750000   50.000000              0.0  2500
# 3       35.61800        63.000000  100.000000              0.0   NaN
# 4       35.91300        84.500000    0.000000              0.0   NaN
# ..           ...              ...         ...              ...   ...
# 57           NaN              NaN         NaN              NaN  2500
# 58           NaN              NaN         NaN              NaN  1750
# 59           NaN              NaN         NaN              NaN  2000
# 60           NaN              NaN         NaN              NaN  2000
# 61           NaN              NaN         NaN              NaN  1500
#
# [62 rows x 13 columns]
# 27 Sires have not had any offspring run in the Futurity, 12 sires are no longer eligible as of the 2021 breeding season

# %%
df2 = df2.dropna(subset=['Fee', '1D Horse'])
df2.shape
# Out:
# (23, 13)

# %%
display(df2.sort_values(by = ['total_offspring'],ascending=False))
display(df2.sort_values(by = ['pct1D'],ascending=False))

display(df2.sort_values(by = ['Adj Average_placing'],ascending=True))
# Out:
#                     Sire  Money_Winner  1D Horse  Normalized_penalties  \
# 15       SLICK BY DESIGN          23.0      74.0              0.084507
# 13      THE GOODBYE LANE          17.0      63.0              0.041667
# 23       BLAZIN JETOLENA          10.0      36.0              0.179487
# 21   BHR FRENCHIES SOCKS           6.0      20.0              0.083333
# 19        SHAWNE BUG LEO           8.0      21.0              0.043478
# 16             TRES SEIS           6.0      19.0              0.250000
# 18      FIREWATER CANYON           0.0       3.0              0.230769
# 24             IRISH PAY           4.0       7.0              0.000000
# 30         FURYOFTHEWIND           6.0      15.0              0.076923
# 7      STREAKIN BOON DOX           6.0      16.0              0.750000
# 26      PC REDWOOD MANNY           2.0       2.0              0.100000
# 9           PRIME TALENT           2.0       6.0              0.500000
# 29  PYC PAINT YOUR WAGON           3.0       6.0              0.000000
# 12         DASHIN DYNAMO           0.0       2.0              0.000000
# 8      NO PRESSURE ON ME           0.0       5.0              0.000000
# 31           TRAFFIC GUY           1.0       4.0              0.333333
# 2        WINNERS VERSION           0.0       2.0              1.000000
# 0       DATS A FRENCHMAN           0.0       1.0              1.333333
# 28      ONE FAMOUS EAGLE           1.0       1.0              0.333333
# 5             JL SIROCCO           0.0       2.0              0.000000
# 33              CARRIZZO           1.0       1.0              1.000000
# 32          JESSES TOPAZ           0.0       0.0              0.000000
# 34  AS GOOD AS NICK GETS           0.0       0.0              2.000000
#
#     total_offspring  Total_no-times  Adj Average_Time  Adj Average_placing  \
# 15             71.0             6.0         37.472779            75.764706
# 13             48.0             2.0         36.963457            60.967391
# 23             39.0             7.0         38.356457            74.371429
# 21             24.0             2.0         37.935609            78.282609
# 19             23.0             1.0         37.867318            74.295455
# 16             20.0             5.0         37.642765            81.323529
# 18             13.0             3.0         37.787091            99.590909
# 24             13.0             0.0         39.298077            86.230769
# 30             13.0             1.0         40.005583            94.041667
# 7              12.0             9.0         36.303429            41.642857
# 26             10.0             1.0         39.663111           105.277778
# 9               8.0             4.0         36.446833            57.083333
# 29              7.0             0.0         39.981571            76.571429
# 12              6.0             0.0         36.739500            81.583333
# 8               6.0             0.0         36.318833            78.000000
# 31              6.0             2.0         41.498000           126.750000
# 2               4.0             4.0         35.576500            64.250000
# 0               3.0             4.0         35.388000            50.000000
# 28              3.0             1.0         39.781500           118.500000
# 5               2.0             0.0         36.176500            76.750000
# 33              2.0             2.0         51.260000           147.500000
# 32              1.0             0.0         42.521000           157.500000
# 34              1.0             2.0               NaN                  NaN
#
#     Average_Time  Average_placing       pct1D  pctMoneyWinners             Fee
# 15    120.311958        80.746479  104.225352        32.394366            3000
# 13     77.781000        62.947917  131.250000        35.416667            6500
# 23    214.203897        83.064103   92.307692        25.641026            5000
# 21    119.604958        81.958333   83.333333        25.000000            4500
# 19     80.662304        78.043478   91.304348        34.782609            4000
# 16    282.888650        96.500000   95.000000        30.000000            9800
# 18    263.880538       109.192308   23.076923         0.000000            2500
# 24     39.298077        86.230769   53.846154        30.769231            2000
# 30    115.228615        97.653846  115.384615        46.153846            4000
# 7     771.996167        93.583333  133.333333        50.000000            2500
# 26    137.852100       110.150000   20.000000        20.000000            1500
# 9     526.835125        90.687500   75.000000        25.000000            2000
# 29     39.981571        76.571429   85.714286        42.857143            6000
# 12     36.739500        81.583333   33.333333         0.000000            1750
# 8      36.318833        78.000000   83.333333         0.000000            2000
# 31    366.477833       122.916667   66.666667        16.666667            2500
# 2    1016.788250       130.750000   50.000000         0.000000            2500
# 0    1343.796000       108.666667   33.333333         0.000000            3000
# 28    366.842000       127.666667   33.333333        33.333333  PRIVATE TREATY
# 5      36.176500        76.750000  100.000000         0.000000            3500
# 33   1024.630000       173.500000   50.000000        50.000000            2500
# 32     42.521000       157.500000    0.000000         0.000000            2000
# 34   1998.000000       194.500000    0.000000         0.000000            3000
#                     Sire  Money_Winner  1D Horse  Normalized_penalties  \
# 7      STREAKIN BOON DOX           6.0      16.0              0.750000
# 13      THE GOODBYE LANE          17.0      63.0              0.041667
# 30         FURYOFTHEWIND           6.0      15.0              0.076923
# 15       SLICK BY DESIGN          23.0      74.0              0.084507
# 5             JL SIROCCO           0.0       2.0              0.000000
# 16             TRES SEIS           6.0      19.0              0.250000
# 23       BLAZIN JETOLENA          10.0      36.0              0.179487
# 19        SHAWNE BUG LEO           8.0      21.0              0.043478
# 29  PYC PAINT YOUR WAGON           3.0       6.0              0.000000
# 8      NO PRESSURE ON ME           0.0       5.0              0.000000
# 21   BHR FRENCHIES SOCKS           6.0      20.0              0.083333
# 9           PRIME TALENT           2.0       6.0              0.500000
# 31           TRAFFIC GUY           1.0       4.0              0.333333
# 24             IRISH PAY           4.0       7.0              0.000000
# 33              CARRIZZO           1.0       1.0              1.000000
# 2        WINNERS VERSION           0.0       2.0              1.000000
# 0       DATS A FRENCHMAN           0.0       1.0              1.333333
# 28      ONE FAMOUS EAGLE           1.0       1.0              0.333333
# 12         DASHIN DYNAMO           0.0       2.0              0.000000
# 18      FIREWATER CANYON           0.0       3.0              0.230769
# 26      PC REDWOOD MANNY           2.0       2.0              0.100000
# 32          JESSES TOPAZ           0.0       0.0              0.000000
# 34  AS GOOD AS NICK GETS           0.0       0.0              2.000000
#
#     total_offspring  Total_no-times  Adj Average_Time  Adj Average_placing  \
# 7              12.0             9.0         36.303429            41.642857
# 13             48.0             2.0         36.963457            60.967391
# 30             13.0             1.0         40.005583            94.041667
# 15             71.0             6.0         37.472779            75.764706
# 5               2.0             0.0         36.176500            76.750000
# 16             20.0             5.0         37.642765            81.323529
# 23             39.0             7.0         38.356457            74.371429
# 19             23.0             1.0         37.867318            74.295455
# 29              7.0             0.0         39.981571            76.571429
# 8               6.0             0.0         36.318833            78.000000
# 21             24.0             2.0         37.935609            78.282609
# 9               8.0             4.0         36.446833            57.083333
# 31              6.0             2.0         41.498000           126.750000
# 24             13.0             0.0         39.298077            86.230769
# 33              2.0             2.0         51.260000           147.500000
# 2               4.0             4.0         35.576500            64.250000
# 0               3.0             4.0         35.388000            50.000000
# 28              3.0             1.0         39.781500           118.500000
# 12              6.0             0.0         36.739500            81.583333
# 18             13.0             3.0         37.787091            99.590909
# 26             10.0             1.0         39.663111           105.277778
# 32              1.0             0.0         42.521000           157.500000
# 34              1.0             2.0               NaN                  NaN
#
#     Average_Time  Average_placing       pct1D  pctMoneyWinners             Fee
# 7     771.996167        93.583333  133.333333        50.000000            2500
# 13     77.781000        62.947917  131.250000        35.416667            6500
# 30    115.228615        97.653846  115.384615        46.153846            4000
# 15    120.311958        80.746479  104.225352        32.394366            3000
# 5      36.176500        76.750000  100.000000         0.000000            3500
# 16    282.888650        96.500000   95.000000        30.000000            9800
# 23    214.203897        83.064103   92.307692        25.641026            5000
# 19     80.662304        78.043478   91.304348        34.782609            4000
# 29     39.981571        76.571429   85.714286        42.857143            6000
# 8      36.318833        78.000000   83.333333         0.000000            2000
# 21    119.604958        81.958333   83.333333        25.000000            4500
# 9     526.835125        90.687500   75.000000        25.000000            2000
# 31    366.477833       122.916667   66.666667        16.666667            2500
# 24     39.298077        86.230769   53.846154        30.769231            2000
# 33   1024.630000       173.500000   50.000000        50.000000            2500
# 2    1016.788250       130.750000   50.000000         0.000000            2500
# 0    1343.796000       108.666667   33.333333         0.000000            3000
# 28    366.842000       127.666667   33.333333        33.333333  PRIVATE TREATY
# 12     36.739500        81.583333   33.333333         0.000000            1750
# 18    263.880538       109.192308   23.076923         0.000000            2500
# 26    137.852100       110.150000   20.000000        20.000000            1500
# 32     42.521000       157.500000    0.000000         0.000000            2000
# 34   1998.000000       194.500000    0.000000         0.000000            3000
#                     Sire  Money_Winner  1D Horse  Normalized_penalties  \
# 7      STREAKIN BOON DOX           6.0      16.0              0.750000
# 0       DATS A FRENCHMAN           0.0       1.0              1.333333
# 9           PRIME TALENT           2.0       6.0              0.500000
# 13      THE GOODBYE LANE          17.0      63.0              0.041667
# 2        WINNERS VERSION           0.0       2.0              1.000000
# 19        SHAWNE BUG LEO           8.0      21.0              0.043478
# 23       BLAZIN JETOLENA          10.0      36.0              0.179487
# 15       SLICK BY DESIGN          23.0      74.0              0.084507
# 29  PYC PAINT YOUR WAGON           3.0       6.0              0.000000
# 5             JL SIROCCO           0.0       2.0              0.000000
# 8      NO PRESSURE ON ME           0.0       5.0              0.000000
# 21   BHR FRENCHIES SOCKS           6.0      20.0              0.083333
# 16             TRES SEIS           6.0      19.0              0.250000
# 12         DASHIN DYNAMO           0.0       2.0              0.000000
# 24             IRISH PAY           4.0       7.0              0.000000
# 30         FURYOFTHEWIND           6.0      15.0              0.076923
# 18      FIREWATER CANYON           0.0       3.0              0.230769
# 26      PC REDWOOD MANNY           2.0       2.0              0.100000
# 28      ONE FAMOUS EAGLE           1.0       1.0              0.333333
# 31           TRAFFIC GUY           1.0       4.0              0.333333
# 33              CARRIZZO           1.0       1.0              1.000000
# 32          JESSES TOPAZ           0.0       0.0              0.000000
# 34  AS GOOD AS NICK GETS           0.0       0.0              2.000000
#
#     total_offspring  Total_no-times  Adj Average_Time  Adj Average_placing  \
# 7              12.0             9.0         36.303429            41.642857
# 0               3.0             4.0         35.388000            50.000000
# 9               8.0             4.0         36.446833            57.083333
# 13             48.0             2.0         36.963457            60.967391
# 2               4.0             4.0         35.576500            64.250000
# 19             23.0             1.0         37.867318            74.295455
# 23             39.0             7.0         38.356457            74.371429
# 15             71.0             6.0         37.472779            75.764706
# 29              7.0             0.0         39.981571            76.571429
# 5               2.0             0.0         36.176500            76.750000
# 8               6.0             0.0         36.318833            78.000000
# 21             24.0             2.0         37.935609            78.282609
# 16             20.0             5.0         37.642765            81.323529
# 12              6.0             0.0         36.739500            81.583333
# 24             13.0             0.0         39.298077            86.230769
# 30             13.0             1.0         40.005583            94.041667
# 18             13.0             3.0         37.787091            99.590909
# 26             10.0             1.0         39.663111           105.277778
# 28              3.0             1.0         39.781500           118.500000
# 31              6.0             2.0         41.498000           126.750000
# 33              2.0             2.0         51.260000           147.500000
# 32              1.0             0.0         42.521000           157.500000
# 34              1.0             2.0               NaN                  NaN
#
#     Average_Time  Average_placing       pct1D  pctMoneyWinners             Fee
# 7     771.996167        93.583333  133.333333        50.000000            2500
# 0    1343.796000       108.666667   33.333333         0.000000            3000
# 9     526.835125        90.687500   75.000000        25.000000            2000
# 13     77.781000        62.947917  131.250000        35.416667            6500
# 2    1016.788250       130.750000   50.000000         0.000000            2500
# 19     80.662304        78.043478   91.304348        34.782609            4000
# 23    214.203897        83.064103   92.307692        25.641026            5000
# 15    120.311958        80.746479  104.225352        32.394366            3000
# 29     39.981571        76.571429   85.714286        42.857143            6000
# 5      36.176500        76.750000  100.000000         0.000000            3500
# 8      36.318833        78.000000   83.333333         0.000000            2000
# 21    119.604958        81.958333   83.333333        25.000000            4500
# 16    282.888650        96.500000   95.000000        30.000000            9800
# 12     36.739500        81.583333   33.333333         0.000000            1750
# 24     39.298077        86.230769   53.846154        30.769231            2000
# 30    115.228615        97.653846  115.384615        46.153846            4000
# 18    263.880538       109.192308   23.076923         0.000000            2500
# 26    137.852100       110.150000   20.000000        20.000000            1500
# 28    366.842000       127.666667   33.333333        33.333333  PRIVATE TREATY
# 31    366.477833       122.916667   66.666667        16.666667            2500
# 33   1024.630000       173.500000   50.000000        50.000000            2500
# 32     42.521000       157.500000    0.000000         0.000000            2000
# 34   1998.000000       194.500000    0.000000         0.000000            3000

# %% [raw]
# #create plots of avg time by sire (box)
#
# Which stallion had the most offspring entered? (bar plot)
# Which stallion’s offspring produced the most horses who placed in the 1D? (bar)
# Who’s offspring had the best average time for the futurity?(box & whiskers)
# Which stallion sired the most money winners? (pct bar plot)

# %%
df2.columns
# Out:
# Index(['Sire', 'Money_Winner', '1D Horse', 'Normalized_penalties',
#        'total_offspring', 'Total_no-times', 'Adj Average_Time',
#        'Adj Average_placing', 'Average_Time', 'Average_placing', 'pct1D',
#        'pctMoneyWinners', 'Fee'],
#       dtype='object')

# %%
#Create Plot of offspring entered
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
x = df2['Sire']
y = df2['total_offspring']
ax.barh(x,y,color="C6")
ax.set_title("Number of Offspring Entered ")
ax.set_xlabel('Number of Offspring')
ax.set_ylabel("Sire")
plt.show()
fig.savefig("Number of Offspring Entered.png", dpi=400, bbox_inches="tight")

# %%
#Create Plot of offspring entered
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
x = df2['Sire']
y = df2['pct1D']
ax.barh(x,y,color="C6")
plt.title("Percentage of Offspring placing in 1D")
plt.xlabel('% of offspring')
plt.ylabel("Sire")
plt.show()

# %%
#Create Plot of offspring entered
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
x = df2['Sire']
y = df2['pctMoneyWinners']
ax.barh(x,y,color="C6")
ax.set_title("Percentage of Offspring winning $")
ax.set_xlabel('% of offspring')
ax.set_ylabel("Sire")
plt.show()
fig.savefig("Percentage of Offspring winning $.png", dpi=400, bbox_inches="tight")

# %%
# to do fix 1D horse calculations
# create box plot of average

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'average'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-54-73e8b57cd5a3> in <module>
# ----> 1 data = [df['average']]
#       2
#       3 fig = plt.figure(figsize =(10, 7))
#       4
#       5 # Creating axes instance
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'average'
